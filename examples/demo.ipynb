# %%
from fieldlist import FieldList
path = "../tests/tuv_pl.grib"

ft = FieldList(path)

# %%
len(ft)
# Out:
# 18

# %%
ft.describe()
# Out:
# <style type="text/css">
# #T_0eea3 th {
#   text-align: left;
# }
# #T_0eea3_row0_col0, #T_0eea3_row0_col1, #T_0eea3_row0_col2, #T_0eea3_row0_col3, #T_0eea3_row0_col4, #T_0eea3_row0_col5, #T_0eea3_row0_col6, #T_0eea3_row0_col7, #T_0eea3_row0_col8, #T_0eea3_row1_col0, #T_0eea3_row1_col1, #T_0eea3_row1_col2, #T_0eea3_row1_col3, #T_0eea3_row1_col4, #T_0eea3_row1_col5, #T_0eea3_row1_col6, #T_0eea3_row1_col7, #T_0eea3_row1_col8, #T_0eea3_row2_col0, #T_0eea3_row2_col1, #T_0eea3_row2_col2, #T_0eea3_row2_col3, #T_0eea3_row2_col4, #T_0eea3_row2_col5, #T_0eea3_row2_col6, #T_0eea3_row2_col7, #T_0eea3_row2_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_0eea3">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eea3_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_0eea3_level0_col1" class="col_heading level0 col1" >date</th>
# ...

# %%
ft[2:5].ls()
# Out:
#   centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# 0  ecmf       v     isobaricInhPa  1000   20180801    1200        0
# 1  ecmf       t     isobaricInhPa   850   20180801    1200        0
# 2  ecmf       u     isobaricInhPa   850   20180801    1200        0
#
#   dataType  number   gridType
# 0    an        0    regular_ll
# 1    an        0    regular_ll
# 2    an        0    regular_ll

# %%
ft.head()
# Out:
#   centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# 0  ecmf       v     isobaricInhPa  1000   20180801    1200        0
# 1  ecmf       t     isobaricInhPa   850   20180801    1200        0
# 2  ecmf       u     isobaricInhPa   850   20180801    1200        0
#
#   dataType  number   gridType
# 0    an        0    regular_ll
# 1    an        0    regular_ll
# 2    an        0    regular_ll

# %% [markdown]
# ### Iteration

# %%
for f in ft[:4]:
    print(type(f))
# Out:
# <class 'fieldlist.fieldlist.FieldList'>
# <class 'fieldlist.fieldlist.FieldList'>
# <class 'fieldlist.fieldlist.FieldList'>
# <class 'fieldlist.fieldlist.FieldList'>

# %% [markdown]
# ### Filter

# %%
g = ft.sel(level=[850, 500])
g.ls()
# Out:
#   centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# 0  ecmf       t     isobaricInhPa   850   20180801    1200        0
# 1  ecmf       u     isobaricInhPa   850   20180801    1200        0
# 2  ecmf       v     isobaricInhPa   850   20180801    1200        0
# 3  ecmf       t     isobaricInhPa   500   20180801    1200        0
# 4  ecmf       u     isobaricInhPa   500   20180801    1200        0
# 5  ecmf       v     isobaricInhPa   500   20180801    1200        0
#
#   dataType  number   gridType
# 0    an        0    regular_ll
# 1    an        0    regular_ll
# 2    an        0    regular_ll
# 3    an        0    regular_ll
# 4    an        0    regular_ll
# 5    an        0    regular_ll

# %%
g = ft.sel({"level": [850, 500]})
g.ls()
# Out:
#   centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# 0  ecmf       t     isobaricInhPa   850   20180801    1200        0
# 1  ecmf       u     isobaricInhPa   850   20180801    1200        0
# 2  ecmf       v     isobaricInhPa   850   20180801    1200        0
# 3  ecmf       t     isobaricInhPa   500   20180801    1200        0
# 4  ecmf       u     isobaricInhPa   500   20180801    1200        0
# 5  ecmf       v     isobaricInhPa   500   20180801    1200        0
#
#   dataType  number   gridType
# 0    an        0    regular_ll
# 1    an        0    regular_ll
# 2    an        0    regular_ll
# 3    an        0    regular_ll
# 4    an        0    regular_ll
# 5    an        0    regular_ll

# %% [markdown]
# ### Metadata

# %%
ft[:8].get("level")
# Out:
# [1000, 1000, 1000, 850, 850, 850, 700, 700]

# %%
ft[:8]["level"]
# Out:
# [1000, 1000, 1000, 850, 850, 850, 700, 700]

# %%
ft[:8].get(["level", "paramId", "centre:l"])
# Out:
# [[1000, 130, 98],
#  [1000, 131, 98],
#  [1000, 132, 98],
#  [850, 130, 98],
#  [850, 131, 98],
#  [850, 132, 98],
#  [700, 130, 98],
#  [700, 131, 98]]

# %%
g = ft[:8].set(level=500)
g.ls()
# Out:
#   centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# 0  ecmf       t     isobaricInhPa   500   20180801    1200        0
# 1  ecmf       u     isobaricInhPa   500   20180801    1200        0
# 2  ecmf       v     isobaricInhPa   500   20180801    1200        0
# 3  ecmf       t     isobaricInhPa   500   20180801    1200        0
# 4  ecmf       u     isobaricInhPa   500   20180801    1200        0
# 5  ecmf       v     isobaricInhPa   500   20180801    1200        0
# 6  ecmf       t     isobaricInhPa   500   20180801    1200        0
# 7  ecmf       u     isobaricInhPa   500   20180801    1200        0
#
#   dataType  number   gridType
# 0    an        0    regular_ll
# 1    an        0    regular_ll
# 2    an        0    regular_ll
# 3    an        0    regular_ll
# 4    an        0    regular_ll
# 5    an        0    regular_ll
# 6    an        0    regular_ll
# 7    an        0    regular_ll

# %%
# Out:
# GribField(u,500,20180801,1200,0,0)
